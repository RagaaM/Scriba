# %% [markdown]
# <a href="https://colab.research.google.com/github/RagaaM/Scriba/blob/main/EffNet-Without-Aug-Franken.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as numpy
import cv2
from matplotlib import pyplot as plt

# %%
imagePath = '/content/drive/MyDrive/SCRIBA/Dataset-Royals/test/Ramses-II/Ramesses_II_8.jpg'
imagePathSaqara = '/content/drive/MyDrive/SCRIBA/dataset-manual-test/train/X1/X1-3.PNG'

# %%
# load the image, swap color channels, and resize it to be a fixed
# 224x224 pixels while ignoring aspect ratio
image = cv2.imread(imagePath)
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
image = cv2.resize(image, (224, 224))   
gaussian_blur = cv2.GaussianBlur(image, (5,5), 1.5)
ret, thresh = cv2.threshold(gaussian_blur, 0, 255, cv2.THRESH_BINARY_INV + 
                                        cv2.THRESH_OTSU)

# %%
# load the image, swap color channels, and resize it to be a fixed
# 224x224 pixels while ignoring aspect ratio
imageS = cv2.imread(imagePathSaqara)
imageS = cv2.cvtColor(imageS, cv2.COLOR_BGR2GRAY)
imageS = cv2.resize(imageS, (224, 224))   
gaussian_blur = cv2.GaussianBlur(imageS, (5,5), 1.5)
ret, threshS = cv2.threshold(gaussian_blur, 0, 255, cv2.THRESH_BINARY_INV + 
                                        cv2.THRESH_OTSU)

# %%
image = cv2.imread(imagePath)
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
equalized_image = cv2.equalizeHist(gray_image)
clahe = cv2.createCLAHE(clipLimit =10, tileGridSize=(8,8))
clahe_image = clahe.apply(gray_image)
gaussian_image = cv2.GaussianBlur(clahe_image, (5,5), 1.5)
ret, otsu_image = cv2.threshold(gaussian_image, 120, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

# %%
# plt.imshow(thresh, cmap='gray')
# plt.axis('off')
# plt.show()

# plt.imshow(image, cmap='gray')
# plt.axis('off')
# plt.show()

plt.imshow(imageS, cmap='gray')
plt.axis('off')
plt.show()

plt.imshow(threshS, cmap='gray')
plt.axis('off')
plt.show()

# %%
datasetPath = '/content/drive/MyDrive/SCRIBA/dataset-manual-test/train/'
LABELS = set(["A5O","D2","D21", "D36", "G17", "I9", "M17", "M23", "N17", "N35","O1","Q3","S29","S34","U1","U7","V28","X1"])

from imutils import paths
import cv2
import os

print("[INFO] loading images...")
imagePaths = list(paths.list_images(datasetPath))
print(imagePaths[0])
data = []
labels = []
# Out:
# [INFO] loading images...
# /content/drive/MyDrive/SCRIBA/dataset-manual-test/train/X1/X1-3.PNG

# %%
import torch
import torchvision.transforms.functional as fn
from PIL import Image
from torchvision.utils import save_image

import numpy as numpy
from matplotlib import pyplot as plt

count = 0
for imagePath in imagePaths:
    #extract the class label from the filename
    label = imagePath.split(os.path.sep)[-2]
    # print("imagePath: ",imagePath)

    # print ("imagePaths",imagePaths)
    # print(label)  
    if label not in LABELS:
        continue
    # print(label)
    # print(count)
    count = count +1
    imgg = Image.open(imagePath)
    resize = fn.resize(imgg, (75,50))
    # print("This is the size of resized image:",resize.size,"\n")
    resize
    # type(resize)
    # convert = resize.convert('RGB')
    # plt.imshow(convert, cmap='gray')
    # plt.axis('off')
    # plt.show()
    # image_converted = convert.save('photo.jpg')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=98x57 at 0x7F1D2F099350>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=53x53 at 0x7F1D2F099490>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=73x62 at 0x7F1D2F099810>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=78x46 at 0x7F1D2F099350>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=29x75 at 0x7F1D2F099DD0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=40x183 at 0x7F1D2F099810>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=162x247 at 0x7F1D2F099490>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=132x147 at 0x7F1D2F099D10>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=89x206 at 0x7F1D2F0991D0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=55x181 at 0x7F1D2F099C90>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=28x79 at 0x7F1D2F099D50>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=25x73 at 0x7F1D2F099790>
# ...

# %%
import torch
import torchvision.transforms.functional as fn
from PIL import Image
from torchvision.utils import save_image

import numpy as numpy
from matplotlib import pyplot as plt

img = '/content/drive/MyDrive/SCRIBA/dataset-manual-test/test/D2/D2-0.PNG'

imgg = Image.open(img)
print("This is size of original image:",imgg.size, "\n")
imgg

resize = fn.resize(imgg, (75,50))
print("This is the size of resized image:",resize.size,"\n")
resize
# type(resize)
# convert = resize.convert('RGB')
# image_converted = convert.save('resized.jpg')
# Out:
# This is size of original image: (141, 166)
#
# This is the size of resized image: (50, 75)
# <PIL.Image.Image image mode=RGBA size=50x75 at 0x7F1D2FB10190>
